# %% [markdown]
# ## valid 阶段

# %%
# !pwd
# Out:
# /data/wangql43/A000Files/A000comp/006kdd/PST-KDD-2024/paper-source-trace

# %%
# !python process_kddcup_data.py
# Out:
# data_dir ...  /data/wangql43/A000Files/A000comp/006kdd/PST-KDD-2024/paper-source-trace/rf/data/PST
# 2024-05-24 01:36:50,510 loading paper_source_trace_train_ans.json ...
# 2024-05-24 01:36:50,587 paper_source_trace_train_ans.json loaded
# 2024-05-24 01:36:50,587 loading paper_source_trace_valid_wo_ans.json ...
# 2024-05-24 01:36:50,607 paper_source_trace_valid_wo_ans.json loaded
# ...
# Reading papers:  51%|█████████████████▍                | 3229405/6275270 [03:06<01:36, 31445.22it/s]2024-05-24 01:40:53,303 reading papers 3230000
# ...
# ...
# 100%|█████████████████████████████████████| 1182/1182 [00:00<00:00, 5151.41it/s]
# number of papers after filtering 16368
# 2024-05-24 01:44:02,468 dumping paper_info_hit_from_dblp.json ...
# 2024-05-24 01:44:02,693 paper_info_hit_from_dblp.json dumped.
# 2024-05-24 01:44:24,523 loading paper_info_hit_from_dblp.json ...
# 2024-05-24 01:44:24,574 paper_info_hit_from_dblp.json loaded
# ...

# %%
# !python model_rf.py  # output at out/kddcup/rf/
# Out:
# Accuracy: 0.9322033898305084
# Precision: 0.9292763157894737
# Recall: 0.9354304635761589
# 2024-05-24 01:56:09,939 loading paper_source_trace_valid_wo_ans.json ...
# 2024-05-24 01:56:09,959 paper_source_trace_valid_wo_ans.json loaded
# 2024-05-24 01:56:09,959 loading paper_info_hit_from_dblp.json ...
# 2024-05-24 01:56:10,073 paper_info_hit_from_dblp.json loaded
# 2024-05-24 01:56:10,104 loading submission_example_valid.json ...
# 2024-05-24 01:56:10,107 submission_example_valid.json loaded
# 100%|█████████████████████████████████████████| 394/394 [01:01<00:00,  6.42it/s]
# 2024-05-24 01:57:11,447 dumping valid_sub_RandomForest.json ...
# 2024-05-24 01:57:11,466 valid_sub_RandomForest.json dumped.

# %%
# !python model_rf.py  # output at out/kddcup/rf/
# Out:
# Accuracy: 0.7110376188507648
# Precision: 0.6817434210526315
# Recall: 0.726555652936021
# 2024-05-24 02:40:51,930 loading paper_source_trace_valid_wo_ans.json ...
# 2024-05-24 02:40:51,955 paper_source_trace_valid_wo_ans.json loaded
# 2024-05-24 02:40:51,955 loading paper_info_hit_from_dblp.json ...
# 2024-05-24 02:40:52,048 paper_info_hit_from_dblp.json loaded
# 2024-05-24 02:40:52,052 loading submission_example_valid.json ...
# 2024-05-24 02:40:52,055 submission_example_valid.json loaded
# 100%|█████████████████████████████████████████| 394/394 [00:56<00:00,  6.96it/s]
# 2024-05-24 02:41:48,634 dumping valid_sub_LGB.json ...
# 2024-05-24 02:41:48,654 valid_sub_LGB.json dumped.

# %% [markdown]
# ## test 阶段

# %%
# !python process_kddcup_data_test.py
# Out:
# data_dir ...  /data/wangql43/A000Files/A000comp/006kdd/PST-KDD-2024/paper-source-trace/rf/data/PST
# 2024-06-05 07:10:28,354 loading paper_source_trace_train_ans.json ...
# 2024-06-05 07:10:28,405 paper_source_trace_train_ans.json loaded
# 2024-06-05 07:10:28,405 loading paper_source_trace_test_wo_ans.json ...
# 2024-06-05 07:10:28,425 paper_source_trace_test_wo_ans.json loaded
# ...
# Reading papers:  51%|█████████████████▍                | 3227478/6275270 [03:01<02:03, 24620.36it/s]2024-06-05 07:14:15,861 reading papers 3230000
# ...
# ...
# 100%|█████████████████████████████████████| 1182/1182 [00:00<00:00, 5056.81it/s]
# number of papers after filtering 17463
# 2024-06-05 07:17:31,364 dumping paper_info_hit_from_dblp.json ...
# 2024-06-05 07:17:31,612 paper_info_hit_from_dblp.json dumped.
# 2024-06-05 07:17:54,510 loading paper_info_hit_from_dblp.json ...
# 2024-06-05 07:17:54,565 paper_info_hit_from_dblp.json loaded
# ...

# %%
# !python model_rf_test.py
# Out:
# seed >>>  0
# Accuracy: 0.7135179826374535
# Precision: 0.671875
# Recall: 0.7353735373537353
# 2024-06-05 07:56:04,603 loading paper_source_trace_test_wo_ans.json ...
# 2024-06-05 07:56:04,626 paper_source_trace_test_wo_ans.json loaded
# 2024-06-05 07:56:04,626 loading paper_info_hit_from_dblp.json ...
# 2024-06-05 07:56:04,786 paper_info_hit_from_dblp.json loaded
# 2024-06-05 07:56:04,790 loading submission_example_test.json ...
# 2024-06-05 07:56:04,795 submission_example_test.json loaded
# 100%|█████████████████████████████████████████| 394/394 [01:02<00:00,  6.26it/s]
# 2024-06-05 07:57:07,732 dumping test_sub_LGB_0.json ...
# 2024-06-05 07:57:07,759 test_sub_LGB_0.json dumped.
# seed >>>  42
# Accuracy: 0.7110376188507648
# Precision: 0.671875
# Recall: 0.7314234556848702
# 2024-06-05 07:58:00,212 loading paper_source_trace_test_wo_ans.json ...
# 2024-06-05 07:58:00,231 paper_source_trace_test_wo_ans.json loaded
# ...
